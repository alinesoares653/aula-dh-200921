# %% [markdown]
# <a href="https://colab.research.google.com/github/alinesoares653/aula-dh-200921/blob/master/vinhos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

arquivo = pd.read_csv('wine_dataset.csv')

# %%
arquivo.head(30)
# Out:
#     fixed_acidity  volatile_acidity  citric_acid  ...  alcohol  quality  style
# 0             7.4             0.700         0.00  ...      9.4        5    red
# 1             7.8             0.880         0.00  ...      9.8        5    red
# 2             7.8             0.760         0.04  ...      9.8        5    red
# 3            11.2             0.280         0.56  ...      9.8        6    red
# 4             7.4             0.700         0.00  ...      9.4        5    red
# 5             7.4             0.660         0.00  ...      9.4        5    red
# 6             7.9             0.600         0.06  ...      9.4        5    red
# 7             7.3             0.650         0.00  ...     10.0        7    red
# 8             7.8             0.580         0.02  ...      9.5        7    red
# 9             7.5             0.500         0.36  ...     10.5        5    red
# 10            6.7             0.580         0.08  ...      9.2        5    red
# 11            7.5             0.500         0.36  ...     10.5        5    red
# 12            5.6             0.615         0.00  ...      9.9        5    red
# 13            7.8             0.610         0.29  ...      9.1        5    red
# 14            8.9             0.620         0.18  ...      9.2        5    red
# 15            8.9             0.620         0.19  ...      9.2        5    red
# 16            8.5             0.280         0.56  ...     10.5        7    red
# 17            8.1             0.560         0.28  ...      9.3        5    red
# 18            7.4             0.590         0.08  ...      9.0        4    red
# 19            7.9             0.320         0.51  ...      9.2        6    red
# 20            8.9             0.220         0.48  ...      9.4        6    red
# 21            7.6             0.390         0.31  ...      9.7        5    red
# 22            7.9             0.430         0.21  ...      9.5        5    red
# 23            8.5             0.490         0.11  ...      9.4        5    red
# 24            6.9             0.400         0.14  ...      9.7        6    red
# 25            6.3             0.390         0.16  ...      9.3        5    red
# 26            7.6             0.410         0.24  ...      9.5        5    red
# 27            7.9             0.430         0.21  ...      9.5        5    red
# 28            7.1             0.710         0.00  ...      9.4        5    red
# 29            7.8             0.645         0.00  ...      9.8        6    red
#
# [30 rows x 13 columns]

# %%
arquivo['style'] = arquivo['style'].replace('red', 0)
arquivo['style'] = arquivo['style'].replace('white',0)
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  alcohol  quality  style
# 0            7.4              0.70         0.00  ...      9.4        5      0
# 1            7.8              0.88         0.00  ...      9.8        5      0
# 2            7.8              0.76         0.04  ...      9.8        5      0
# 3           11.2              0.28         0.56  ...      9.8        6      0
# 4            7.4              0.70         0.00  ...      9.4        5      0
#
# [5 rows x 13 columns]

# %%
y= arquivo['style']
x = arquivo.drop('style', axis = 1)

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, train_size = 0.7)

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelo = ExtraTreesClassifier()
modelo.fit(x_treino, y_treino)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
resultado = modelo.score(x_teste, y_teste)
print(resultado)
# Out:
# 1.0
